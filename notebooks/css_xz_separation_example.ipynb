# %% [markdown]
# # CSS X/Z separated decoding
#
# This notebook demonstrates the two independent CSS components used in this educational project: one graph for Z-type errors and one dual-oriented graph for X-type errors.

# %%
import random
from src.evaluate import run_css_single_shot

# %%
rng = random.Random(7)
shot = run_css_single_shot(distance=5, physical_error_rate=0.03, rng=rng, decoder_name='mwpm')
shot
